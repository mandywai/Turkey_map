# %%
#!pip install osmnx

import osmnx as ox
import geopandas as gpd

# %%
## Data from Openstreetmap [39.9029, 32.8587, 32.8787, 39.8942]

## https://www.openstreetmap.org/#map=16/39.8985/32.8660
Ankara = ox.graph_from_xml('Ankara.osm')

# %%
ox.plot_graph(Ankara)
# Out:
# (<Figure size 800x800 with 1 Axes>, <AxesSubplot:>)
